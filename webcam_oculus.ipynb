# %%
a = euler_from_quaternion([0.0,1.0,0.5,0.2])
a[0]*180.0/numpy.pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6f1fdc27384d> in <module>()
# ----> 1 a = euler_from_quaternion([0.0,1.0,0.5,0.2])
#       2 a[0]*180.0/numpy.pi
#
# NameError: name 'euler_from_quaternion' is not defined

# %%
import numpy as np
import cv2
from algos import *
from rift import PyRift
import thread
import transformation

from Arduino import Arduino
import time

# board = Arduino('9600') #plugged in via USB, serial com at rate 9600
# board.Servos.attach(6) #declare servo on pin 9
# board.Servos.attach(7) #declare servo on pin 9

cap = cv2.VideoCapture(0)
cap2 = cv2.VideoCapture(2)

cap.set(3,420)
cap.set(4,340)
cap.set(5, 60)

cap2.set(3,420)
cap2.set(4,340)
cap2.set(5, 60)

par = Parameters
cv2.namedWindow( "Display frame",cv2.WINDOW_NORMAL);
cv2.resizeWindow("Display frame",1260,510);
n=0
# foo = PyRift()
while(n < 100000):
    n+=1
    # Capture frame-by-frame
    
    ret, frame = cap.read()
    ret2, frame2 = cap2.read()
    
    fxL, cxL, fyL, cyL =  210 ,225, 310  ,200
    matrix = create_distortion_matrix(
                fxL, cxL, fyL, cyL
            )
   
    frame = transform(frame, matrix)
    frame2 = transform(frame2, matrix)
    frame = translate(frame, 20,0)
    frame2 = translate(frame2, -20,0)
    composite_frame = join_images(
                frame,
                frame2,
            )
    composite_frame = cv2.resize(composite_frame,(0,0), fx=1.5, fy=1.5)
    # Display the resulting frame
    cv2.imshow("Display frame", composite_frame);
    
#     foo.poll()
    
#     angles = euler_from_quaternion([foo.rotation[0], foo.rotation[1], foo.rotation[2], foo.rotation[3]])
#     angle1 = int(angles[0]*50.0/np.pi)+50
#     angle2 = int(angles[1]*50.0/np.pi)+50
#     angle3 = int(angles[2]*50.0/np.pi)
    
#     print angle1, angle2, angle3
    
#     board.Servos.write(6, angle1) #move servo on pin 9 to 0 degrees
#     time.sleep(0.001)
#     board.Servos.write(7, angle2) #move servo on pin 9 to 0 degrees
#     cv2.imshow('frame',composite_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cap2.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-7c07cc935d0a> in <module>()
#      42
#      43     frame = transform(frame, matrix)
# ---> 44     frame2 = transform(frame2, matrix)
#      45     frame = translate(frame, 20,0)
#      46     frame2 = translate(frame2, -20,0)
#
# /Users/louis/Documents/RemotePresence/algos.pyc in transform(image, matrix, k1, k2)
#      47         image,
#      48         matrix,
# ---> 49         np.array([k1, k2, 0, 0, 0])
#      50     )
#      51
#
# error: /tmp/opencv20160105-22383-1i90kl/opencv-2.4.12/modules/imgproc/src/undistort.cpp:173: error: (-215) dst.data != src.data in function undistort

# %%
np.pi
# Out:
# 3.141592653589793

# %%
from Arduino import Arduino
import time
from rift import PyRift
import numpy as np

board = Arduino('9600') #plugged in via USB, serial com at rate 9600
board.pinMode(13, "OUTPUT")
board.Servos.attach(6) #declare servo on pin 9
board.Servos.attach(7) #declare servo on pin 9
n=0
foo = PyRift()
while(True):
    n+=1
    
    foo.poll()
    
    angles = euler_from_quaternion([foo.rotation[0], foo.rotation[1], foo.rotation[2], foo.rotation[3]])
    angle1 = -int(angles[0]*180.0/np.pi)+100
    angle2 = int(angles[1]*180.0/np.pi)+50
    angle3 = -int(angles[2]*180.0/np.pi)
    
    print angle1, angle2, angle3
    
    board.Servos.write(6, angle1) #move servo on pin 9 to 0 degrees
    time.sleep(0.001)
    board.Servos.write(7, angle2) #move servo on pin 9 to 0 degrees
    
board.Servos.detach(6)
board.Servos.detach(7)
# Out:
# 100 50 0
# 100 50 0
# 100 50 0
# 100 50 0
# 100 50 0
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 37 59 15
# 36 60 14
# 36 61 14
# 35 61 13
# 35 61 13
# 35 61 13
# 35 62 13
# 35 62 13
# 35 62 13
# 35 61 13
# 35 61 13
# 35 60 13
# 35 60 13
# 37 56 12
# 37 54 11
# 37 54 10
# ...

# %%
board.Servos.detach(6)
board.Servos.detach(7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a0976b56061c> in <module>()
# ----> 1 board.Servos.detach(6)
#       2 board.Servos.detach(7)
#
# NameError: name 'board' is not defined

# %%
eval('2+2')
# Out:
# 4
